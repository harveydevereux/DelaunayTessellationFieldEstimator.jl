# %%
include("DelaunayTessellationFieldEstimator.jl")
using DelaunayTessellationFieldEstimator.DTFE

import PyPlot.imshow

using Plots
# Out:
# WARNING: replacing module DelaunayTessellationFieldEstimator

# %%
X = readdlm("ExampleData.txt",',',Float64);

# %%
scatter(X[:,1],X[:,2])

# %%
tic()
grid = DTFE(X);
toc();
# Out:
# elapsed time: 0.025566206 seconds

# %%
imshow(grid,vmin=0,vmax=5*std(grid),origin="lower")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f733dd34f90>)
# PyObject <matplotlib.image.AxesImage object at 0x7f732afa4210>
